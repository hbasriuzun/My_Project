# %%
from csv_processor import veri_oku
import pandas as pd

data = veri_oku("loan.csv")
df = pd.DataFrame(data)

print(df)
# Out:
# Kod yürütülemiyor, oturum atıldı. Lütfen Çekirdeği yeniden başlatmayı deneyin.
# Geçerli hücrede veya önceki bir hücrede kod yürütülürken Çekirdek kilitlendi. Hatanın olası nedenini belirlemek için lütfen hücrelerdeki kodu gözden geçirin. Daha fazla bilgi için <a href='https://aka.ms/vscodeJupyterKernelCrash'>buraya</a> tıklayın. Daha fazla ayrıntı için Jupyter <a href='command:jupyter.viewOutput'>günlüğünü</a> görüntüleyin.

# %%
import pandas as pd
from csv_processor import veri_oku_py


# C tarafında veriyi oku
dosya_ismi = "bank.csv"
data_char = veri_oku_py(dosya_ismi)  # C tarafından char* olarak dönen veri

# Veriyi C tarafından dönen char* veriden bir Python stringine dönüştürün

# Python stringini kullanabilirsiniz
df = pd.DataFrame(data_char)
# df = pd.DataFrame(data_char, columns=["Tek_Sutun_Veri"])
# df = df["Tek_Sutun_Veri"].str.split(",", expand=True)
df
# Out:
#          0                1          2            3          4          5   \
# 0     "age"            "job"  "marital"  "education"  "default"  "balance"
# 1        30     "unemployed"  "married"    "primary"       "no"       1787
# 2        33       "services"  "married"  "secondary"       "no"       4789
# 3        35     "management"   "single"   "tertiary"       "no"       1350
# 4        30     "management"  "married"   "tertiary"       "no"       1476
# ...     ...              ...        ...          ...        ...        ...
# 4517     33       "services"  "married"  "secondary"       "no"       -333
# 4518     57  "self-employed"  "married"   "tertiary"      "yes"      -3313
# 4519     57     "technician"  "married"  "secondary"       "no"        295
# 4520     28    "blue-collar"  "married"  "secondary"       "no"       1137
# 4521     44   "entrepreneur"   "single"   "tertiary"       "no"       1136
#
# ...

# %%
import pandas as pd
from csv_processor import veri_oku_py


# C tarafında veriyi oku
dosya_ismi = "bank.csv"
data_char = veri_oku_py(dosya_ismi)  # C tarafından char* olarak dönen veri

# Veriyi C tarafından dönen char* veriden bir Python stringine dönüştürün

# Python stringini kullanabilirsiniz
df = pd.DataFrame(data_char)
# df = pd.DataFrame(data_char, columns=["Tek_Sutun_Veri"])
# df = df["Tek_Sutun_Veri"].str.split(",", expand=True)
df
# Out:
#          0                1          2            3          4          5   \
# 0     "age"            "job"  "marital"  "education"  "default"  "balance"
# 1        30     "unemployed"  "married"    "primary"       "no"       1787
# 2        33       "services"  "married"  "secondary"       "no"       4789
# 3        35     "management"   "single"   "tertiary"       "no"       1350
# 4        30     "management"  "married"   "tertiary"       "no"       1476
# ...     ...              ...        ...          ...        ...        ...
# 4517     33       "services"  "married"  "secondary"       "no"       -333
# 4518     57  "self-employed"  "married"   "tertiary"      "yes"      -3313
# 4519     57     "technician"  "married"  "secondary"       "no"        295
# 4520     28    "blue-collar"  "married"  "secondary"       "no"       1137
# 4521     44   "entrepreneur"   "single"   "tertiary"       "no"       1136
#
# ...

# %%
import pandas as pd
from csv_processor import veri_oku_py


# C tarafında veriyi oku
dosya_ismi = "bank-additional-full.csv"
data_char = veri_oku_py(dosya_ismi)  # C tarafından char* olarak dönen veri

# Veriyi C tarafından dönen char* veriden bir Python stringine dönüştürün

# Python stringini kullanabilirsiniz
df = pd.DataFrame(data_char)
# df = pd.DataFrame(data_char, columns=["Tek_Sutun_Veri"])
# df = df["Tek_Sutun_Veri"].str.split(",", expand=True)
df
# Out:
# Kod yürütülemiyor, oturum atıldı. Lütfen Çekirdeği yeniden başlatmayı deneyin.
# Geçerli hücrede veya önceki bir hücrede kod yürütülürken Çekirdek kilitlendi. Hatanın olası nedenini belirlemek için lütfen hücrelerdeki kodu gözden geçirin. Daha fazla bilgi için <a href='https://aka.ms/vscodeJupyterKernelCrash'>buraya</a> tıklayın. Daha fazla ayrıntı için Jupyter <a href='command:jupyter.viewOutput'>günlüğünü</a> görüntüleyin.

# %%
import pandas as pd
from csv_processor import veri_oku_py


# C tarafında veriyi oku
dosya_ismi = "bank.csv"
data_char = veri_oku_py(dosya_ismi)  # C tarafından char* olarak dönen veri

# Veriyi C tarafından dönen char* veriden bir Python stringine dönüştürün

# Python stringini kullanabilirsiniz
df = pd.DataFrame(data_char)
# df = pd.DataFrame(data_char, columns=["Tek_Sutun_Veri"])
# df = df["Tek_Sutun_Veri"].str.split(",", expand=True)
df.dtypes
# Out:
# 0     object
# 1     object
# 2     object
# 3     object
# 4     object
# 5     object
# 6     object
# 7     object
# 8     object
# 9     object
# 10    object
# 11    object
# 12    object
# 13    object
# 14    object
# 15    object
# 16    object
# dtype: object

# %%
import pandas as pd
from csv_processor import veri_oku_py


# C tarafında veriyi oku
dosya_ismi = "bank-additional-full.csv"
data_char = veri_oku_py(dosya_ismi)  # C tarafından char* olarak dönen veri

# Veriyi C tarafından dönen char* veriden bir Python stringine dönüştürün

# Python stringini kullanabilirsiniz
df = pd.DataFrame(data_char)
# df = pd.DataFrame(data_char, columns=["Tek_Sutun_Veri"])
# df = df["Tek_Sutun_Veri"].str.split(",", expand=True)
df
# Out:
# Kod yürütülemiyor, oturum atıldı. Lütfen Çekirdeği yeniden başlatmayı deneyin.
# Geçerli hücrede veya önceki bir hücrede kod yürütülürken Çekirdek kilitlendi. Hatanın olası nedenini belirlemek için lütfen hücrelerdeki kodu gözden geçirin. Daha fazla bilgi için <a href='https://aka.ms/vscodeJupyterKernelCrash'>buraya</a> tıklayın. Daha fazla ayrıntı için Jupyter <a href='command:jupyter.viewOutput'>günlüğünü</a> görüntüleyin.
